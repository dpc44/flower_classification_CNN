# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

import pathlib
import splitfolders
import scipy.io
import pandas as pd
import shutil
import glob

# %% [markdown]
# # testing materials

# %%
parent_dir ="full_images"
data_dir = pathlib.Path(parent_dir)

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 8189

# %%
roses = list(data_dir.glob('image102/*'))
PIL.Image.open(str(roses[500]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=667x500 at 0x20C562BF250>

# %% [markdown]
# # open matlab get labels

# %%
matfile = scipy.io.loadmat('imagelabels.mat')

# %%
x = matfile['labels'].T

# %%
x
# Out:
# array([[77],
#        [77],
#        [77],
#        ...,
#        [62],
#        [62],
#        [62]], dtype=uint8)

# %% [markdown]
# # create folder

# %%
#folder = np.unique(x)
#folder_string = folder.astype(str)

# %%
#create_dir ="images"
#for ide in folder_string:
#    path = os.path.join(create_dir, ide)
#    os.mkdir(path)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-9-b118ed4f9161> in <module>
#       2 for ide in folder_string:
#       3     path = os.path.join(create_dir, ide)
# ----> 4     os.mkdir(path)
#       5
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'images\\1'

# %% [markdown]
# # copy images

# %%
#create list
obj = {}
for i in range(1, 103):
    obj['class'+str(i)] = []

#obj['class77'].append(2)
#i = 77
#obj['class'+str(i)].append(1)
#print(obj['class'+str(i)])

# %%
count = 1

for i in x:
    obj['class'+str(i[0])].append(count)
    count+=1

# %%
for key in obj:
    obj[key] = [str(item).zfill(5) for item in obj[key]]

# %%
print(obj['class102'])

# %%
for i in range(1, 103):
    dst_dir = f"images\\{i}"
    src_dir = "full_images\\image102"
    for imageName in obj['class'+str(i)]:
        shutil.copy(os.path.join(src_dir, f"image_{imageName}.jpg"), dst_dir)

# %% [markdown]
# # slipt folder

# %%
splitfolders.ratio("images", output="", seed=1337, ratio=(.64, .16 , .2), group_prefix=None)

# %%
splitfolders.ratio("images", output="", seed=1337, ratio=(.74, .13 , .13), group_prefix=None)
